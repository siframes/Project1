# %% [markdown]
# <a href="https://colab.research.google.com/github/siframes/Project1/blob/main/Baran_Erol_Future_forecasting_Modell_Meta_USD_30_Day_back_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Meta Aktie Vola. Index::**
# 30 days back + 30 days forward prediction
#
# Stichtag 20.04.2022 vorbörslich.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 217 + np.random.randn(30)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 208, where=(ys > 232), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# Volatility Index Python
# by Baran Erol
#
# anhand der letzten 30 Tage des Aktienschlusskurses konnte der zukünftige Aktienkurs mit der durchschnittlich zu erwartende Volatilität visualisiert und statistisch errechnet werden.
#
# 208$ - 233$ top to bottom (20.04.2022 Datum) der statistischen Erhebung.
#
# Siehe Datensatz Yahoo
#
# ![Meta.png](data:image/png;base64,...)
